# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("/Users/macbook/Desktop/XPLAINAV1_OPTIMISED_GRADUATION/XplainaV1/all-courses-hybrid-45-skills.csv")

# %%
##Here we define our skills ( 45 skills that make about 70 % of our skills)


skill_cols = [
    'javascript','website','technical product management','financial accounting',
    'application development','system security','digital marketing','microsoft excel',
    'regulations and compliance','market analysis','swift programming','people management',
    'network architecture','theoretical computer science','bayesian network','negotiation',
    'people analysis','search engine optimization','sap','machine learning software',
    'user experience','database application','angular','basic descriptive statistics',
    'jira','spatial analysis','interactive design','strategy and operations',
    'big data','python programming','media strategy & planning','financial analysis',
    'human learning','google app engine','writing','android development','software testing',
    'risk management','game theory','web development','supply chain and logistics',
    'user experience design','agile software development','internet of things','power bi'
]

len(skill_cols)
# Out:
# 45

# %%
    # 3. Build feature columns
df['text_all'] = (
            df['course_title'].fillna('') + ' ' +
            df["skills_text"].fillna("")
    
    )

# %%
X_text = df['text_all']
Y = df[skill_cols].values

# %%
skill_cols = [
    col for col in df.columns 
    if col not in ['course_title','rating','review_count','skills_list','platform','level','duration','skills_text','text_all']
]
print(skill_cols)
print(len(skill_cols))
# Out:
# ['javascript', 'website', 'technical product management', 'financial accounting', 'application development', 'system security', 'digital marketing', 'microsoft excel', 'regulations and compliance', 'market analysis', 'swift programming', 'people management', 'network architecture', 'theoretical computer science', 'bayesian network', 'negotiation', 'people analysis', 'search engine optimization', 'sap', 'machine learning software', 'user experience', 'database application', 'angular', 'basic descriptive statistics', 'jira', 'spatial analysis', 'interactive design', 'strategy and operations', 'big data', 'python programming', 'media strategy & planning', 'financial analysis', 'human learning', 'google app engine', 'writing', 'android development', 'software testing', 'risk management', 'game theory', 'web development', 'supply chain and logistics', 'user experience design', 'agile software development', 'internet of things', 'power bi']
# 45

# %%
print(df.columns.tolist())
# Out:
# ['course_title', 'rating', 'review_count', 'skills_list', 'platform', 'level', 'duration', 'skills_text', 'javascript', 'website', 'technical product management', 'financial accounting', 'application development', 'system security', 'digital marketing', 'microsoft excel', 'regulations and compliance', 'market analysis', 'swift programming', 'people management', 'network architecture', 'theoretical computer science', 'bayesian network', 'negotiation', 'people analysis', 'search engine optimization', 'sap', 'machine learning software', 'user experience', 'database application', 'angular', 'basic descriptive statistics', 'jira', 'spatial analysis', 'interactive design', 'strategy and operations', 'big data', 'python programming', 'media strategy & planning', 'financial analysis', 'human learning', 'google app engine', 'writing', 'android development', 'software testing', 'risk management', 'game theory', 'web development', 'supply chain and logistics', 'user experience design', 'agile software development', 'internet of things', 'power bi', 'text_all']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_text, Y, test_size=0.2, random_state=42
)

# %%
text_clf = Pipeline([
    ('tfidf', TfidfVectorizer(
        max_features=20000,
        ngram_range=(1,2),
        min_df=2
    )),
    ('clf', OneVsRestClassifier(
        LogisticRegression(max_iter=1000)
    ))
])

# %%
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=20000, min_df=2,
#                                  ngram_range=(1, 2))),
#                 ('clf',
#                  OneVsRestClassifier(estimator=LogisticRegression(max_iter=1000)))])

# %%
y_pred = text_clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred, target_names=skill_cols))
# Out:
#                               precision    recall  f1-score   support
#
#                   javascript       0.96      0.82      0.88       136
#                      website       1.00      0.61      0.76        75
# technical product management       1.00      0.84      0.91        86
#         financial accounting       1.00      0.96      0.98       156
#      application development       1.00      0.89      0.94       114
#              system security       1.00      0.92      0.96       104
#            digital marketing       0.91      0.72      0.81        40
#              microsoft excel       0.99      0.97      0.98       263
#   regulations and compliance       1.00      0.57      0.73        21
#              market analysis       1.00      0.88      0.94        77
#            swift programming       1.00      0.71      0.83        31
#            people management       1.00      0.88      0.93        32
#         network architecture       1.00      0.88      0.94        78
# theoretical computer science       1.00      0.95      0.98       106
#             bayesian network       1.00      0.97      0.98        32
#                  negotiation       1.00      0.29      0.44         7
#              people analysis       1.00      0.82      0.90        34
#   search engine optimization       0.98      0.82      0.90        68
#                          sap       0.98      0.92      0.95        50
#    machine learning software       0.96      0.97      0.97       110
#              user experience       0.99      0.94      0.96       109
#         database application       1.00      0.97      0.98       167
#                      angular       1.00      0.74      0.85        42
# basic descriptive statistics       1.00      0.86      0.93       102
#                         jira       1.00      0.27      0.43        11
#             spatial analysis       0.00      0.00      0.00         3
#           interactive design       1.00      0.71      0.83        21
#      strategy and operations       1.00      0.94      0.97       100
#                     big data       0.91      0.47      0.62        43
#           python programming       0.99      0.95      0.97       275
#    media strategy & planning       1.00      0.94      0.97        99
#           financial analysis       0.99      0.97      0.98       158
#               human learning       1.00      0.60      0.75        35
#            google app engine       1.00      0.98      0.99       225
#                      writing       1.00      0.52      0.68        56
#          android development       1.00      0.91      0.96        82
#             software testing       0.97      0.85      0.91        79
#              risk management       1.00      0.74      0.85        61
#                  game theory       1.00      0.87      0.93        98
#              web development       1.00      0.11      0.20         9
#   supply chain and logistics       1.00      0.75      0.86        20
#       user experience design       0.96      0.97      0.97       102
#   agile software development       1.00      0.88      0.94        33
#           internet of things       1.00      1.00      1.00       836
#                     power bi       0.98      0.82      0.89        97
#
#                    micro avg       0.99      0.90      0.95      4483
#                    macro avg       0.97      0.78      0.85      4483
#                 weighted avg       0.99      0.90      0.94      4483
#                  samples avg       0.66      0.64      0.65      4483
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def test_course(text):
    pred = text_clf.predict([text])[0]
    proba = text_clf.predict_proba([text])[0]

    results = []
    for i, val in enumerate(pred):
        if val == 1:
            results.append((skill_cols[i], round(proba[i], 3)))

    return sorted(results, key=lambda x: -x[1])

# %%
def test_course_skills(text, pipeline):
    """
    Predicts skills and their probabilities for a given course text.
    
    Args:
        text (str): The course description text.
        pipeline (Pipeline): The fitted scikit-learn Pipeline object.
        
    Returns:
        list: A sorted list of (skill_name, probability) tuples.
    """
    # 1. Access the fitted OneVsRestClassifier from the pipeline
    ovr_classifier = pipeline.named_steps['clf']
    
    # 2. Get the prediction and probabilities
    pred = pipeline.predict([text])[0]
    proba = pipeline.predict_proba([text])[0]
    
    # 3. The classes_ attribute of OneVsRestClassifier stores the order 
    #    of the labels, which matches the order of probabilities.
    #    For multi-label tasks, the classes_ will be 0, 1, 2... for your N labels.
    #    We must ensure the skill names align with the probability order.
    #    In your case, this order should match your skill_cols list.

    results = []
    # ovr_classifier.classes_ is an array [0, 1, 2, ..., 44] for 45 skills
    for i, label_index in enumerate(ovr_classifier.classes_):
        # label_index will be 0, 1, 2, ...
        
        # Check if the class was predicted (val == 1)
        if pred[i] == 1: 
            skill_name = skill_cols[label_index] # Match the index to the name
            probability = proba[i]
            results.append((skill_name, round(probability, 3)))
            
    # Return the results sorted by probability in descending order
    return sorted(results, key=lambda x: -x[1])


# Example Usage (replace your existing call):
test_course_skills("This course teaches python programming, data science, deep learning, and google app engine.", text_clf)
# Out:
# [('google app engine', np.float64(0.889)),
#  ('python programming', np.float64(0.842))]

# %%
test_course("This course teaches python programming, data science, deep learning, and google app engine.")
# Out:
# [('google app engine', np.float64(0.889)),
#  ('python programming', np.float64(0.842))]

# %%
i = 10
text = df.loc[i, "text_all"]
print(text)
test_course(text)
# Out:
# Generative AI for Everyone writing | strategy
# [('writing', np.float64(0.568))]

# %%
vectorizer = text_clf.named_steps["tfidf"]
clf = text_clf.named_steps["clf"]

# %%
skill = "python programming"
skill_index = skill_cols.index(skill)
model_for_skill = clf.estimators_[skill_index]

# %%
X_train_vec = vectorizer.transform(X_train)

# %%
import sys
print(sys.executable) ##macbook@192 XplainaV1 % /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install shap
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3

# %%
# !pip install lime==0.2.0.1
# !pip install ipython==8.12.0
# Out:
# Requirement already satisfied: lime==0.2.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lime==0.2.0.1) (3.10.6)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lime==0.2.0.1) (2.3.3)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lime==0.2.0.1) (1.16.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lime==0.2.0.1) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lime==0.2.0.1) (1.7.2)
# Requirement already satisfied: scikit-image>=0.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from lime==0.2.0.1) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (3.6)
# Requirement already satisfied: pillow>=10.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-image>=0.12->lime==0.2.0.1) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn>=0.18->lime==0.2.0.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn>=0.18->lime==0.2.0.1) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->lime==0.2.0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->lime==0.2.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->lime==0.2.0.1) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->lime==0.2.0.1) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->lime==0.2.0.1) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from matplotlib->lime==0.2.0.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->lime==0.2.0.1) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipython==8.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (8.12.0)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython==8.12.0) (0.2.0)
# Requirement already satisfied: decorator in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (0.1.7)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython==8.12.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (2.19.2)
# Requirement already satisfied: stack-data in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (4.9.0)
# Requirement already satisfied: appnope in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython==8.12.0) (0.1.4)
# Requirement already satisfied: wcwidth in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.0) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython==8.12.0) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython==8.12.0) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython==8.12.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython==8.12.0) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython==8.12.0) (0.2.3)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack-data in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: appnope in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.4)
# Requirement already satisfied: wcwidth in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/macbook/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import shap

vectorizer = text_clf.named_steps["tfidf"]
clf = text_clf.named_steps["clf"]
X_train_vec = vectorizer.transform(X_train)

def explain_course_with_shap(course_text, max_skills=3, top_words=5):
    """
    Returns SHAP-based word importances for the top predicted skills for this course.
    """
    # 1) Get predictions & probabilities for this course
    sample_vec = vectorizer.transform([course_text])
    proba = clf.predict_proba(sample_vec)[0]  # shape: (n_skills,)
    pred = (proba >= 0.5).astype(int)        # threshold; adjust if you want

    # 2) Choose which skills to explain: predicted = 1, sorted by prob
    skill_probs = [
        (skill_cols[i], proba[i], i)
        for i in range(len(skill_cols))
        if pred[i] == 1
    ]
    if not skill_probs:
        # no skill strongly predicted → just take top skills by prob
        skill_probs = sorted(
            [(skill_cols[i], proba[i], i) for i in range(len(skill_cols))],
            key=lambda x: -x[1]
        )[:max_skills]
    else:
        skill_probs = sorted(skill_probs, key=lambda x: -x[1])[:max_skills]

    feature_names = vectorizer.get_feature_names_out()
    explanations = {}

    # 3) For each selected skill, compute SHAP values
    for skill_name, p, idx in skill_probs:
        model_for_skill = clf.estimators_[idx]

        explainer = shap.LinearExplainer(
            model_for_skill,
            X_train_vec,
            feature_perturbation="interventional"
        )
        shap_vals = explainer.shap_values(sample_vec)[0]  # 1D: (n_features,)

        # Get top contributing words
        # sort features by absolute SHAP value
        top_idx = np.argsort(-np.abs(shap_vals))[:top_words]
        word_contribs = [
            (feature_names[j], float(shap_vals[j]))
            for j in top_idx
        ]

        explanations[skill_name] = {
            "probability": float(p),
            "word_contributions": word_contribs,
        }

    return explanations

# %%
sample_text = X_test.iloc[6]
print(sample_text)

shap_explanations = explain_course_with_shap(sample_text, max_skills=45, top_words=5)

for skill_name, info in shap_explanations.items():
    print(f"\nSkill: {skill_name} (p={info['probability']:.3f})")
    for w, val in info["word_contributions"]:
        sign = "+" if val >= 0 else "-"
        print(f"  {sign} {w}: {val:.4f}")
# Out:
# Project Planning & Management For Software & IT Engineers leadership development | leadership and management
#
# Skill: risk management (p=0.048)
#   + management: 1.5426
#   + leadership: 0.3150
#   + leadership and: 0.1818
#   + and management: 0.1758
#   + and: 0.1104
#
# Skill: strategy and operations (p=0.042)
#   + management: 0.7832
#   + leadership: 0.6135
#   + and: 0.3479
#   + leadership and: 0.3325
#   + and management: 0.3243
#
# Skill: agile software development (p=0.029)
#   + software: 0.6580
#   + development: 0.4513
#   + project: 0.2733
#   + management: 0.2459
#   + leadership: 0.2280
#
# Skill: people management (p=0.018)
#   + management: 0.8266
#   + leadership: 0.4527
#   + development: 0.2492
#   + leadership and: 0.1610
#   + and management: 0.1602
#
# Skill: negotiation (p=0.015)
#   + leadership: 0.7827
#   + management: 0.3370
#   + leadership and: 0.2120
#   + and management: 0.2112
#   + leadership development: 0.1961
#
# Skill: software testing (p=0.013)
#   + software: 1.0246
#   - management: -0.0959
#   + development: 0.0755
#   - leadership: -0.0333
#   + development leadership: 0.0311
#
# Skill: internet of things (p=0.013)
#   - of: -0.2919
#   - internet: -0.2638
#   - of things: -0.2637
#   - internet of: -0.2637
#   - things: -0.2628
#
# Skill: financial analysis (p=0.011)
#   + management: 0.9407
#   - financial: -0.2941
#   + leadership: 0.2689
#   + and management: 0.1481
#   + leadership and: 0.1396
#
# Skill: application development (p=0.009)
#   + development: 0.7027
#   + software: 0.2393
#   - application: -0.1643
#   - application development: -0.0587
#   + project: 0.0545
#
# Skill: regulations and compliance (p=0.009)
#   + management: 0.3883
#   + leadership: 0.3666
#   + and: 0.2779
#   + leadership and: 0.1971
#   + and management: 0.1960
#
# Skill: python programming (p=0.008)
#   + software: 0.1401
#   - programming: -0.1224
#   - python: -0.0953
#   + engineers: 0.0655
#   + leadership and: 0.0556
#
# Skill: supply chain and logistics (p=0.008)
#   + management: 0.5017
#   + leadership: 0.2995
#   + and: 0.1999
#   + leadership and: 0.1279
#   + and management: 0.1269
#
# Skill: user experience (p=0.007)
#   + management: 0.2072
#   + leadership: 0.1869
#   - user: -0.1308
#   + software: 0.1063
#   + development: 0.1056
#
# Skill: people analysis (p=0.007)
#   + management: 0.4489
#   + leadership: 0.2441
#   + development: 0.2204
#   + leadership and: 0.0941
#   + and management: 0.0934
#
# Skill: human learning (p=0.007)
#   + leadership: 0.4533
#   + management: 0.2421
#   + leadership and: 0.1906
#   + and management: 0.1898
#   + planning: 0.1397
#
# Skill: market analysis (p=0.007)
#   + management: 0.4114
#   + leadership: 0.2447
#   + and management: 0.1447
#   + leadership and: 0.1412
#   - analysis: -0.0803
#
# Skill: technical product management (p=0.006)
#   + management: 0.8911
#   - leadership: -0.1168
#   + it: 0.1161
#   - technical: -0.0757
#   - product: -0.0713
#
# Skill: writing (p=0.006)
#   - management: -0.1059
#   + planning: 0.0756
#   - writing: -0.0457
#   + leadership and: 0.0415
#   + and management: 0.0410
#
# Skill: system security (p=0.006)
#   + software: 0.4027
#   + management: 0.1700
#   + leadership: 0.1552
#   - system: -0.1549
#   + leadership and: 0.0959
#
# Skill: financial accounting (p=0.006)
#   + management: 0.6980
#   - financial: -0.2965
#   - development: -0.0613
#   + leadership: 0.0611
#   - analysis: -0.0481
#
# Skill: javascript (p=0.005)
#   - javascript: -0.3049
#   - management: -0.2072
#   + development: 0.1908
#   - leadership: -0.1085
#   + software: 0.0526
#
# Skill: android development (p=0.005)
#   + development: 0.8463
#   - management: -0.1846
#   - leadership: -0.0900
#   - android: -0.0540
#   - for: -0.0306
#
# Skill: microsoft excel (p=0.005)
#   - excel: -0.1121
#   - microsoft: -0.0950
#   - development: -0.0658
#   + software: 0.0639
#   + management: 0.0619
#
# Skill: database application (p=0.005)
#   + development: 0.4719
#   - application: -0.1509
#   - database: -0.1381
#   - management: -0.0717
#   - leadership: -0.0488
#
# Skill: big data (p=0.004)
#   + management: 0.2054
#   - data: -0.1313
#   + leadership: 0.0577
#   + software: 0.0556
#   + leadership and: 0.0500
#
# Skill: google app engine (p=0.004)
#   - engine: -0.2242
#   - google: -0.2239
#   - app: -0.1637
#   - management: -0.1586
#   - app engine: -0.1174
#
# Skill: basic descriptive statistics (p=0.004)
#   - development: -0.0508
#   - leadership: -0.0387
#   - statistics: -0.0385
#   - basic descriptive: -0.0342
#   - descriptive: -0.0339
#
# Skill: game theory (p=0.004)
#   - game: -0.2092
#   - management: -0.1137
#   - game theory: -0.1027
#   - theory: -0.0924
#   - project: -0.0363
#
# Skill: media strategy & planning (p=0.004)
#   + planning: 0.7103
#   - strategy: -0.1784
#   - media: -0.1166
#   - leadership: -0.0853
#   - project: -0.0400
#
# Skill: digital marketing (p=0.004)
#   - digital: -0.0880
#   + planning: 0.0638
#   - digital marketing: -0.0616
#   - marketing: -0.0586
#   - project: -0.0395
#
# Skill: power bi (p=0.004)
#   - management: -0.0974
#   - power: -0.0546
#   - project: -0.0410
#   + software: 0.0393
#   - for: -0.0343
#
# Skill: website (p=0.003)
#   - management: -0.2066
#   - leadership: -0.1234
#   - website: -0.1103
#   - software: -0.0594
#   - development: -0.0437
#
# Skill: sap (p=0.003)
#   - sap: -0.1180
#   - leadership: -0.0895
#   + management: 0.0470
#   - development: -0.0449
#   + planning: 0.0438
#
# Skill: search engine optimization (p=0.003)
#   - engine: -0.1599
#   + it: 0.0680
#   - optimization: -0.0564
#   - search: -0.0553
#   - engine optimization: -0.0552
#
# Skill: user experience design (p=0.003)
#   - user: -0.1271
#   + development: 0.0812
#   - user experience: -0.0797
#   - experience: -0.0784
#   - design: -0.0451
#
# Skill: network architecture (p=0.003)
#   + software: 0.1408
#   - architecture: -0.0823
#   - network: -0.0621
#   + leadership: 0.0491
#   + leadership and: 0.0369
#
# Skill: jira (p=0.003)
#   + software: 0.2701
#   + project: 0.1818
#   + development: 0.0912
#   + for software: 0.0847
#   - leadership: -0.0457
#
# Skill: angular (p=0.002)
#   - angular: -0.2171
#   - management: -0.1740
#   + development: 0.1069
#   - leadership: -0.0747
#   - for: -0.0411
#
# Skill: swift programming (p=0.002)
#   + development: 0.1617
#   - management: -0.1058
#   - leadership: -0.0572
#   - programming: -0.0414
#   - and: -0.0214
#
# Skill: interactive design (p=0.002)
#   + development: 0.1132
#   - management: -0.0822
#   - leadership: -0.0648
#   - design: -0.0508
#   + and: 0.0353
#
# Skill: theoretical computer science (p=0.002)
#   + software: 0.1270
#   - science: -0.1030
#   - computer: -0.0977
#   - management: -0.0755
#   - computer science: -0.0526
#
# Skill: web development (p=0.002)
#   + development: 0.3567
#   + software: 0.1933
#   + leadership: 0.0505
#   + management: 0.0394
#   + leadership and: 0.0334
#
# Skill: bayesian network (p=0.001)
#   - management: -0.0809
#   - network: -0.0625
#   - leadership: -0.0400
#   - learning: -0.0211
#   - project: -0.0166
#
# Skill: machine learning software (p=0.001)
#   + software: 0.2284
#   - learning: -0.1253
#   - machine learning: -0.1020
#   - machine: -0.1007
#   - leadership: -0.0727
#
# Skill: spatial analysis (p=0.001)
#   + software: 0.0514
#   + planning: 0.0337
#   - analysis: -0.0308
#   - spatial: -0.0279
#   - management: -0.0279
# /Users/macbook/Library/Python/3.9/lib/python/site-packages/shap/explainers/_linear.py:99: FutureWarning: The feature_perturbation option is now deprecated in favor of using the appropriate masker (maskers.Independent, maskers.Partition or maskers.Impute).
#   warnings.warn(wmsg, FutureWarning)

# %%
labels_to_explain = [
    skill_cols.index("system security"),
    skill_cols.index("python programming"),
    skill_cols.index("internet of things"),
    skill_cols.index("javascript"),
    skill_cols.index("technical product management"),
    

    skill_cols.index("machine learning software")
]

exp = explainer.explain_instance(
    sample_text,
    predict_proba,
    num_features=10,
    labels=labels_to_explain
)

# You can then inspect exp.as_list(label=label_id) for each skill
for label_id in labels_to_explain:
    print("\nSkill:", skill_cols[label_id])
    print(exp.as_list(label=label_id))
# Out:
# Skill: system security
# [(np.str_('Software'), 0.0023669337393710274), (np.str_('For'), -0.0008342386735574883), (np.str_('management'), 0.0007284204079633584), (np.str_('and'), 0.00071620035017187), (np.str_('development'), -0.0005507785736602306), (np.str_('Engineers'), -0.00046772530873557833), (np.str_('leadership'), 0.00031888064543813535), (np.str_('Project'), -0.00031470366768000975), (np.str_('IT'), 0.00030981483921739675), (np.str_('Planning'), -0.0002791173340866631)]
#
# Skill: python programming
# [(np.str_('Software'), 0.0013431271990860247), (np.str_('For'), -0.0010196101917609415), (np.str_('and'), 0.0008126141100248586), (np.str_('development'), 0.0003854802177267072), (np.str_('Engineers'), 0.00031382508973094403), (np.str_('management'), 0.0003103745653180739), (np.str_('Project'), -0.00017746944712452507), (np.str_('IT'), -0.00016271155651032118), (np.str_('Management'), 0.0001303394655347922), (np.str_('leadership'), 7.374990113310405e-05)]
#
# Skill: internet of things
# [(np.str_('and'), -0.0010414289055189734), (np.str_('For'), 0.0009498669109582611), (np.str_('management'), -0.0008443773872016217), (np.str_('development'), -0.0007631643705476116), (np.str_('Software'), 0.0006980795727957491), (np.str_('Project'), -0.0006609478120799294), (np.str_('leadership'), -0.00047614790485136084), (np.str_('Engineers'), -0.0003050315314590405), (np.str_('Management'), -0.0002624694955322887), (np.str_('IT'), 0.00016885044214458438)]
#
# Skill: javascript
# [(np.str_('development'), 0.0016774875897031254), (np.str_('leadership'), -0.0014590820898982037), (np.str_('management'), -0.001064789815327551), (np.str_('Management'), -0.0010422178124348655), (np.str_('For'), -0.0005282496036861519), (np.str_('Software'), 0.00041874546262421773), (np.str_('Project'), -0.0004109781253506922), (np.str_('and'), 0.0003918186104926834), (np.str_('Planning'), -0.0002560703497878321), (np.str_('IT'), 0.00013661400123427382)]
#
# Skill: technical product management
# [(np.str_('management'), 0.003455891542387786), (np.str_('Management'), 0.0032752560851834734), (np.str_('leadership'), -0.003150769981539143), (np.str_('and'), -0.001570073452918423), (np.str_('For'), -0.00134738054063218), (np.str_('Project'), -0.0010459998009339424), (np.str_('development'), -0.0009539789820698276), (np.str_('Engineers'), -0.0006861260129893177), (np.str_('Software'), -0.0006528086961037646), (np.str_('IT'), 0.00046052520932410567)]
#
# Skill: machine learning software
# [(np.str_('Software'), 0.00029733664825350024), (np.str_('leadership'), -0.0001393066499216588), (np.str_('and'), -8.773342572097079e-05), (np.str_('For'), -4.153108388286772e-05), (np.str_('development'), -3.2267264851536015e-05), (np.str_('management'), -3.203551920800863e-05), (np.str_('Project'), -3.0036879064658002e-05), (np.str_('Management'), -2.3518693583558917e-05), (np.str_('Engineers'), -1.9161284398226637e-05), (np.str_('Planning'), -1.7373280560699606e-05)]

# %%
# preparing our made model for saving .... 

import joblib
joblib.dump(text_clf, "MultiLabelModel.pkl")
# Out:
# ['MultiLabelModel.pkl']

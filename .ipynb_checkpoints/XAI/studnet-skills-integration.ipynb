# %%
import joblib

model = joblib.load("text_classifier.pkl")

# %%
skill_cols = [
    'javascript','technical product management','financial accounting',
    'application development','system security','digital marketing','microsoft excel',
    'regulations and compliance','market analysis','swift programming','people management',
    'network architecture','theoretical computer science','bayesian network','negotiation',
    'people analysis','search engine optimization','sap','machine learning software',
    'user experience','database application','angular','basic descriptive statistics',
    'jira','spatial analysis','interactive design','strategy and operations',
    'big data','python programming','media strategy & planning','financial analysis',
    'human learning','google app engine','writing','android development','software testing',
    'risk management','game theory','web development','supply chain and logistics',
    'user experience design','agile software development','internet of things','power bi'
]

# %%
def test_course(text):
    pred = model.predict([text])[0]
    proba = model.predict_proba([text])[0]

    results = []
    for i, val in enumerate(pred):
        if val == 1:
            results.append((skill_cols[i], round(proba[i], 3)))

    return sorted(results, key=lambda x: -x[1])

# %%
test_course("Google Data Analytics")
# Out:
# []

# %%
def test_course_skills(text, pipeline):
    """
    Predicts skills and their probabilities for a given course text.
    
    Args:
        text (str): The course description text.
        pipeline (Pipeline): The fitted scikit-learn Pipeline object.
        
    Returns:
        list: A sorted list of (skill_name, probability) tuples.
    """
    # 1. Access the fitted OneVsRestClassifier from the pipeline
    ovr_classifier = pipeline.named_steps['clf']
    
    # 2. Get the prediction and probabilities
    pred = pipeline.predict([text])[0]
    proba = pipeline.predict_proba([text])[0]
    
    # 3. The classes_ attribute of OneVsRestClassifier stores the order 
    #    of the labels, which matches the order of probabilities.
    #    For multi-label tasks, the classes_ will be 0, 1, 2... for your N labels.
    #    We must ensure the skill names align with the probability order.
    #    In your case, this order should match your skill_cols list.

    results = []
    # ovr_classifier.classes_ is an array [0, 1, 2, ..., 44] for 45 skills
    for i, label_index in enumerate(ovr_classifier.classes_):
        # label_index will be 0, 1, 2, ...
        
        # Check if the class was predicted (val == 1)
        if pred[i] == 1: 
            skill_name = skill_cols[label_index] # Match the index to the name
            probability = proba[i]
            results.append((skill_name, round(probability, 3)))
            
    # Return the results sorted by probability in descending order
    return sorted(results, key=lambda x: -x[1])


# Example Usage (replace your existing call):
test_course_skills("Cloud Application Development Foundations", model)
# Out:
# [('system security', np.float64(0.997)), ('angular', np.float64(0.977))]

# %%
import pandas as pd

# %%
student_data = pd.read_csv("student_responses.csv")

# %%
student_data_without_timestamp = student_data.drop(columns=["Timestamp"])

# %%
student_data_without_timestamp.to_csv("student_responses_without_timestamp.csv", index=False)

# %%
student_data_without_timestamp
# Out:
#      1) Javascript  2) Wordpress  3) Technical product management  \
# 0                4             6                                5
# 1                7             3                                5
# 2                7             1                                6
# 3                1             1                                1
# 4                4             5                                7
# ..             ...           ...                              ...
# 103              5             1                                5
# 104              5             5                                5
# 105              6             8                                7
# 106              5             5                                1
# 107              4             1                                1
#
#      4) Financial accounting  5) Application development  6) System security  \
# 0                          8                           6                   2
# 1                          7                           6                   4
# 2                          1                           3                   6
# 3                          1                           1                   1
# 4                          6                           5                   6
# ..                       ...                         ...                 ...
# 103                        3                           7                   5
# 104                        5                           5                   5
# 105                        4                           8                   7
# 106                        1                           1                   1
# 107                        1                           3                   1
#
#      7) Digital marketing  8) Microsoft excel  9) Regulations and compliance  \
# 0                      10                   8                             10
# 1                       8                   9                              4
# 2                       8                   6                              1
# 3                       1                   1                              1
# 4                       8                  10                             10
# ..                    ...                 ...                            ...
# 103                     2                   8                              8
# 104                     5                   5                              5
# 105                     6                   8                              6
# 106                     2                   5                              1
# 107                     1                   3                              1
#
#      10) Market analysis  ...  36) Android development  37) Software testing  \
# 0                      5  ...                        4                     6
# 1                     10  ...                        1                     8
# 2                      1  ...                        1                     5
# 3                      1  ...                        1                     1
# 4                      8  ...                        6                     6
# ..                   ...  ...                      ...                   ...
# 103                    5  ...                        6                     5
# 104                    5  ...                        5                     5
# 105                    5  ...                        8                     6
# 106                    1  ...                        1                     1
# 107                    2  ...                        1                     1
#
#      38) Risk management  39) Game theory  40) Web development  \
# 0                      9               10                    4
# 1                      8                1                    7
# 2                     10                1                   10
# 3                      1                1                    1
# 4                      8                6                    6
# ..                   ...              ...                  ...
# 103                    4                1                    8
# 104                    5                5                    5
# 105                    7                1                   10
# 106                    2                1                    1
# 107                    1                1                    6
#
#      41) Supply chain and logistics  42) User experience design  \
# 0                                 5                           6
# 1                                 7                           6
# 2                                 1                          10
# 3                                 1                           1
# 4                                 7                           7
# ..                              ...                         ...
# 103                               1                           7
# 104                               5                           5
# 105                               5                           9
# 106                               1                           1
# 107                               1                           6
#
#      43) Agile software development  44) Internet of things  45) Power bi
# 0                                 3                       7             3
# 1                                 5                       7             7
# 2                                10                      10             1
# 3                                 1                       1             1
# 4                                 5                       5             5
# ..                              ...                     ...           ...
# 103                               6                       5             1
# 104                               5                       5             5
# 105                               1                      10             2
# 106                               1                       1             1
# 107                               4                       1             1
#
# [108 rows x 45 columns]

# %%
updated_student_data = pd.read_csv("student_responses_without_timestamp.csv")
updated_student_data
# Out:
#      1) Javascript  2) Wordpress  3) Technical product management  \
# 0                4             6                                5
# 1                7             3                                5
# 2                7             1                                6
# 3                1             1                                1
# 4                4             5                                7
# ..             ...           ...                              ...
# 103              5             1                                5
# 104              5             5                                5
# 105              6             8                                7
# 106              5             5                                1
# 107              4             1                                1
#
#      4) Financial accounting  5) Application development  6) System security  \
# 0                          8                           6                   2
# 1                          7                           6                   4
# 2                          1                           3                   6
# 3                          1                           1                   1
# 4                          6                           5                   6
# ..                       ...                         ...                 ...
# 103                        3                           7                   5
# 104                        5                           5                   5
# 105                        4                           8                   7
# 106                        1                           1                   1
# 107                        1                           3                   1
#
#      7) Digital marketing  8) Microsoft excel  9) Regulations and compliance  \
# 0                      10                   8                             10
# 1                       8                   9                              4
# 2                       8                   6                              1
# 3                       1                   1                              1
# 4                       8                  10                             10
# ..                    ...                 ...                            ...
# 103                     2                   8                              8
# 104                     5                   5                              5
# 105                     6                   8                              6
# 106                     2                   5                              1
# 107                     1                   3                              1
#
#      10) Market analysis  ...  36) Android development  37) Software testing  \
# 0                      5  ...                        4                     6
# 1                     10  ...                        1                     8
# 2                      1  ...                        1                     5
# 3                      1  ...                        1                     1
# 4                      8  ...                        6                     6
# ..                   ...  ...                      ...                   ...
# 103                    5  ...                        6                     5
# 104                    5  ...                        5                     5
# 105                    5  ...                        8                     6
# 106                    1  ...                        1                     1
# 107                    2  ...                        1                     1
#
#      38) Risk management  39) Game theory  40) Web development  \
# 0                      9               10                    4
# 1                      8                1                    7
# 2                     10                1                   10
# 3                      1                1                    1
# 4                      8                6                    6
# ..                   ...              ...                  ...
# 103                    4                1                    8
# 104                    5                5                    5
# 105                    7                1                   10
# 106                    2                1                    1
# 107                    1                1                    6
#
#      41) Supply chain and logistics  42) User experience design  \
# 0                                 5                           6
# 1                                 7                           6
# 2                                 1                          10
# 3                                 1                           1
# 4                                 7                           7
# ..                              ...                         ...
# 103                               1                           7
# 104                               5                           5
# 105                               5                           9
# 106                               1                           1
# 107                               1                           6
#
#      43) Agile software development  44) Internet of things  45) Power bi
# 0                                 3                       7             3
# 1                                 5                       7             7
# 2                                10                      10             1
# 3                                 1                       1             1
# 4                                 5                       5             5
# ..                              ...                     ...           ...
# 103                               6                       5             1
# 104                               5                       5             5
# 105                               1                      10             2
# 106                               1                       1             1
# 107                               4                       1             1
#
# [108 rows x 45 columns]

# %%
print("Student response shape:", updated_student_data.shape)
updated_student_data.head()
# Out:
# Student response shape: (108, 45)
#    1) Javascript  2) Wordpress  3) Technical product management  \
# 0              4             6                                5
# 1              7             3                                5
# 2              7             1                                6
# 3              1             1                                1
# 4              4             5                                7
#
#    4) Financial accounting  5) Application development  6) System security  \
# 0                        8                           6                   2
# 1                        7                           6                   4
# 2                        1                           3                   6
# 3                        1                           1                   1
# 4                        6                           5                   6
#
#    7) Digital marketing  8) Microsoft excel  9) Regulations and compliance  \
# 0                    10                   8                             10
# 1                     8                   9                              4
# 2                     8                   6                              1
# 3                     1                   1                              1
# 4                     8                  10                             10
#
#    10) Market analysis  ...  36) Android development  37) Software testing  \
# 0                    5  ...                        4                     6
# 1                   10  ...                        1                     8
# 2                    1  ...                        1                     5
# 3                    1  ...                        1                     1
# 4                    8  ...                        6                     6
#
#    38) Risk management  39) Game theory  40) Web development  \
# 0                    9               10                    4
# 1                    8                1                    7
# 2                   10                1                   10
# 3                    1                1                    1
# 4                    8                6                    6
#
#    41) Supply chain and logistics  42) User experience design  \
# 0                               5                           6
# 1                               7                           6
# 2                               1                          10
# 3                               1                           1
# 4                               7                           7
#
#    43) Agile software development  44) Internet of things  45) Power bi
# 0                               3                       7             3
# 1                               5                       7             7
# 2                              10                      10             1
# 3                               1                       1             1
# 4                               5                       5             5
#
# [5 rows x 45 columns]

# %%
print(updated_student_data.columns.tolist())
# Out:
# ['1) Javascript', '2) Wordpress', '3) Technical product management', '4) Financial accounting', '5) Application development', '6) System security', '7) Digital marketing', '8) Microsoft excel', '9) Regulations and compliance', '10) Market analysis', '11) Swift programming', '12) People management', '13) Network architecture', '14) Theoretical computer science', '15) Bayesian network', '16) Negotiation', '17) People analysis', '18) Search engine optimization', '19) Sap', '20) machine learning software', '21) User experience', '22) Database application', '23) Angular', '24) Basic descriptive statistics', '25) Jira', '26) Spatial analysis', '27) Interactive design', '28) Strategy and operations', '29) Big data', '30) Python programming', '31) Media strategy & planning', '32) Financial analysis', '33) Human learning', '34) Google app engine', '35) Writing', '36) Android development', '37) Software testing', '38) Risk management', '39) Game theory', '40) Web development', '41) Supply chain and logistics', '42) User experience design', '43) Agile software development', '44) Internet of things', '45) Power bi']

# %%
print("Number of course skills:", len(skill_cols))
# Out:
# Number of course skills: 44

# %%
# Remove leading/trailing spaces in column names
updated_student_data.columns = updated_student_data.columns.str.strip()

# Lowercase / match with course model skill columns
updated_student_data.columns = updated_student_data.columns.str.lower()
updated_student_data.columns = updated_student_data.columns.str.replace(" ", " ")

# %%
# Ensure course skill_cols match student_df columns
normalized_skill_cols = [s.lower() for s in skill_cols]

print("Normalized skill columns:")
print(normalized_skill_cols)
# Out:
# Normalized skill columns:
# ['javascript', 'technical product management', 'financial accounting', 'application development', 'system security', 'digital marketing', 'microsoft excel', 'regulations and compliance', 'market analysis', 'swift programming', 'people management', 'network architecture', 'theoretical computer science', 'bayesian network', 'negotiation', 'people analysis', 'search engine optimization', 'sap', 'machine learning software', 'user experience', 'database application', 'angular', 'basic descriptive statistics', 'jira', 'spatial analysis', 'interactive design', 'strategy and operations', 'big data', 'python programming', 'media strategy & planning', 'financial analysis', 'human learning', 'google app engine', 'writing', 'android development', 'software testing', 'risk management', 'game theory', 'web development', 'supply chain and logistics', 'user experience design', 'agile software development', 'internet of things', 'power bi']

# %%
import re

# Load student CSV
student_df = pd.read_csv("student_responses_without_timestamp.csv")

# Function to clean column names
def clean_column(col):
                     
    col = re.sub(r"^\d+\)\s*", "", col)    # remove "1) ", "2) " etc
    col = col.lower()                      # lowercase
 
 
   
   
    return col

# Clean all columns
student_df.columns = [clean_column(c) for c in student_df.columns]
print(student_df.columns.tolist())
# Out:
# ['javascript', 'wordpress', 'technical product management', 'financial accounting', 'application development', 'system security', 'digital marketing', 'microsoft excel', 'regulations and compliance', 'market analysis', 'swift programming', 'people management', 'network architecture', 'theoretical computer science', 'bayesian network', 'negotiation', 'people analysis', 'search engine optimization', 'sap', 'machine learning software', 'user experience', 'database application', 'angular', 'basic descriptive statistics', 'jira', 'spatial analysis', 'interactive design', 'strategy and operations', 'big data', 'python programming', 'media strategy & planning', 'financial analysis', 'human learning', 'google app engine', 'writing', 'android development', 'software testing', 'risk management', 'game theory', 'web development', 'supply chain and logistics', 'user experience design', 'agile software development', 'internet of things', 'power bi']

# %%
student_skill_matrix = student_df[normalized_skill_cols].copy()

print("Student skill matrix shape:", student_skill_matrix.shape)
student_skill_matrix.head()
# Out:
# Student skill matrix shape: (108, 44)
#    javascript  technical product management  financial accounting  \
# 0           4                             5                     8
# 1           7                             5                     7
# 2           7                             6                     1
# 3           1                             1                     1
# 4           4                             7                     6
#
#    application development  system security  digital marketing  \
# 0                        6                2                 10
# 1                        6                4                  8
# 2                        3                6                  8
# 3                        1                1                  1
# 4                        5                6                  8
#
#    microsoft excel  regulations and compliance  market analysis  \
# 0                8                          10                5
# 1                9                           4               10
# 2                6                           1                1
# 3                1                           1                1
# 4               10                          10                8
#
#    swift programming  ...  android development  software testing  \
# 0                  5  ...                    4                 6
# 1                  2  ...                    1                 8
# 2                  1  ...                    1                 5
# 3                  1  ...                    1                 1
# 4                  8  ...                    6                 6
#
#    risk management  game theory  web development  supply chain and logistics  \
# 0                9           10                4                           5
# 1                8            1                7                           7
# 2               10            1               10                           1
# 3                1            1                1                           1
# 4                8            6                6                           7
#
#    user experience design  agile software development  internet of things  \
# 0                       6                           3                   7
# 1                       6                           5                   7
# 2                      10                          10                  10
# 3                       1                           1                   1
# 4                       7                           5                   5
#
#    power bi
# 0         3
# 1         7
# 2         1
# 3         1
# 4         5
#
# [5 rows x 44 columns]

# %%
student_need_matrix = 10 - student_skill_matrix

student_need_matrix.head()
# Out:
#    javascript  technical product management  financial accounting  \
# 0           6                             5                     2
# 1           3                             5                     3
# 2           3                             4                     9
# 3           9                             9                     9
# 4           6                             3                     4
#
#    application development  system security  digital marketing  \
# 0                        4                8                  0
# 1                        4                6                  2
# 2                        7                4                  2
# 3                        9                9                  9
# 4                        5                4                  2
#
#    microsoft excel  regulations and compliance  market analysis  \
# 0                2                           0                5
# 1                1                           6                0
# 2                4                           9                9
# 3                9                           9                9
# 4                0                           0                2
#
#    swift programming  ...  android development  software testing  \
# 0                  5  ...                    6                 4
# 1                  8  ...                    9                 2
# 2                  9  ...                    9                 5
# 3                  9  ...                    9                 9
# 4                  2  ...                    4                 4
#
#    risk management  game theory  web development  supply chain and logistics  \
# 0                1            0                6                           5
# 1                2            9                3                           3
# 2                0            9                0                           9
# 3                9            9                9                           9
# 4                2            4                4                           3
#
#    user experience design  agile software development  internet of things  \
# 0                       4                           7                   3
# 1                       4                           5                   3
# 2                       0                           0                   0
# 3                       9                           9                   9
# 4                       3                           5                   5
#
#    power bi
# 0         7
# 1         3
# 2         9
# 3         9
# 4         5
#
# [5 rows x 44 columns]

# %%
student_skill_matrix.to_csv("student_skills_clean.csv", index=False)
student_need_matrix.to_csv("student_need_vectors.csv", index=False)
